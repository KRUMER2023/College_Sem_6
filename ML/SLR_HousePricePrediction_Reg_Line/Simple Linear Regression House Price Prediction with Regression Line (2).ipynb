# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\\Users\\gaura\\Downloads\\homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker='+')
plt.show()

# %%
new_df = df.drop('price',axis='columns')
new_df
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
price = df.price
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
# Create linear regression object
reg = linear_model.LinearRegression()
reg.fit(new_df,price)
# Out:
# LinearRegression()

# %%
# Predict price of a home with area = 3300 sqr ft

# %%
reg.predict([[3300]])
# Out:
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
# Y = m * X + b (m is coefficient and b is intercept)

# %%
3300*135.78767123 + 180616.43835616432
# Out:
# 628715.7534151643

# %%
# The house price is given above for 3300 Square Feet Rs 628715.7534151643

# %%
# Now Predict the price of a home with area = 5000 sqr ft

# %%
reg.predict([[5000]])
# Out:
# array([859554.79452055])

# %%
#the price of a home with area = 5000 sqr ft is 859554.79452055

# %%
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker='+')
price = reg.coef_ * new_df + reg.intercept_ #This calculate prediction price using regression formula #Creates a smooth list of predicted prices to draw a straight regression line.
plt.plot(new_df, price, color='red', label='Linear Regression Line') #Exact Value of new_df and Predicted Price Values used to draw the smooth line
plt.legend()
plt.show()
